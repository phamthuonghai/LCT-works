# %%
import pickle
import pandas as pd
import numpy as np
from collections import Counter

from tqdm import tqdm

from gensim import models
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer, ENGLISH_STOP_WORDS

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook
from sklearn.manifold import TSNE

output_notebook()
tsne_model = TSNE(n_components=2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3e778942-8616-4b2e-bcde-de4dac306fd2">Loading BokehJS ...</span>
#     </div>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c", 
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5", 
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f", 
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5"
])

# %%
tweets = pd.read_pickle('./data/data_tweets_selected.pkl')

# %% [markdown]
# ## Without author aggregation

# %%
with open('./models/doc2vec_sep_model.kmeans', 'rb') as pickle_file:
    doc2vec_sep_kmeans = pickle.load(pickle_file)

doc2vec_sep_model = models.Doc2Vec.load('./models/doc2vec_sep_model.model')

tsne_kmeans_sep = tsne_model.fit_transform(doc2vec_sep_kmeans.transform(doc2vec_sep_model.docvecs)[:10000])

# %% [markdown]
# ### Topic word list

# %%
MY_ENGLISH_STOP_WORDS = set(['rt'])
MY_ENGLISH_STOP_WORDS.update(ENGLISH_STOP_WORDS)

# %%
sep_vectorizer = TfidfVectorizer(min_df=3, lowercase=True, stop_words=MY_ENGLISH_STOP_WORDS)
sep_tfidf = sep_vectorizer.fit_transform(tweets.apply(lambda row: ' '.join(row.text), axis=1))

sep_feature_array = np.array(sep_vectorizer.get_feature_names())
for topic in range(0,20):
    tf_row = sum(sep_tfidf[[idx for idx, tp in enumerate(doc2vec_sep_kmeans.labels_) if tp == topic]])
    tfidf_sorting = np.argsort(tf_row.toarray()).flatten()[::-1]
    print('Topic %d: %s' % (topic, ' '.join(sep_feature_array[tfidf_sorting][:20])))
# Out:
# Topic 0: like love code new people just use day know make mind life news time want best things follow 10 need
# Topic 1: july 2016 えどがわイケメン pm tos null mdbjss gaga lady xxx afe 08 29 mtvhottest 09 07 15 05 17 16
# Topic 2: new https video just news need trump says like watch time life home love man help people set red great
# Topic 3: new news 2016 july pm black free business says shoes size jobs air make like best tech video trump watch
# Topic 4: 2016 july pm just free new utc follow code available want like resolved black 10 tweet cest join post lit
# Topic 5: love just like 2016 july people life new want know time girl follow man day good pm things tos tweet
# Topic 6: just like https love best ur want need trump girl make new 2016 time people today july day know got
# Topic 7: new july just like news 2016 free love shoes https follow 10 size iphone wear black win time sex make
# Topic 8: huuugs like new code love home free just use time black want 10 need life people tweet check follow news
# Topic 9: 10 new 12 just news 11 need shoes people 15 size free black best like make resolved video know nike
# Topic 10: like people just want love know time right trump https man god need girl person black really fuck world way
# Topic 11: new size black best free news shoes nike air great like deals watch good year white need jordan big make
# Topic 12: new 2016 july news free black just shoes like size make pm best 10 air video follow use nike https
# Topic 13: love like make people know just day mind man news follow hi new life following time want happy way best
# Topic 14: just like away news people want new make time day best right video good love trump way going need life
# Topic 15: 2016 july pm tos えどがわイケメン null mdbjss gaga lady xxx 10 ca 12 01 20 afe 15 13 17 16
# Topic 16: love life time know like want day people girl world just home need man things way sex summer happy good
# Topic 17: 10 july 2016 15 20 12 11 pm new 30 25 just 13 14 shoes make size 100 news 16
# Topic 18: like code new love use people free just need 10 news life want black best wear day make know time
# Topic 19: news new code want love 25 just gold people like https order watch use win day live trump help need

# %% [markdown]
# ### Viz

# %%
plot_kmeans_sep = bp.figure(plot_width=900, plot_height=700,
                            x_axis_type=None, y_axis_type=None, min_border=1,
                            tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave")

plot_kmeans_sep.scatter(x=tsne_kmeans_sep[:,0], y=tsne_kmeans_sep[:,1], 
                        color=colormap[doc2vec_sep_kmeans.labels_[:10000]],
                        source=bp.ColumnDataSource({
                            "tweet": [' '.join(t) for t in tweets[:10000].text],
                            "cluster": doc2vec_sep_kmeans.labels_[:10000]
                        }))

hover = plot_kmeans_sep.select(dict(type=HoverTool))
hover.tooltips={"tweet": "@tweet - cluster: @cluster"}
show(plot_kmeans_sep)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4b741c1-e50d-4f57-806f-6a81d9dc687d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f4b741c1-e50d-4f57-806f-6a81d9dc687d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4b741c1-e50d-4f57-806f-6a81d9dc687d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4b741c1-e50d-4f57-806f-6a81d9dc687d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fb341a78-0342-4522-847f-66b569519fe9":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dd5d255c-ec4b-4a5d-b390-99ed7d012000","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":""},"id":"0420c62d-c0c4-465f-ba2b-d9b7e8317395","type":"Title"},{"attributes":{"overlay":{"id":"dd5d255c-ec4b-4a5d-b390-99ed7d012000","type":"BoxAnnotation"},"plot":{"id":"6c115f24-b127-405a-a0d5-fd2dcf587046","subtype":"Figure","type":"Plot"}},"id":"caa11f72-80ef-4e12-9b07-11d9a61886c8","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"57f7b6b2-fbd9-442a-bef7-3dec4ab9aaf5","type":"DataRange1d"},{"attributes":{"callback":null},"id":"13a8af84-0293-4f37-a803-0bec123c1451","type":"DataRange1d"},{"attributes":{"callback":null,"plot":{"id":"6c115f24-b127-405a-a0d5-fd2dcf587046","subtype":"Figure","type":"Plot"},"tooltips":[["tweet","@tweet - cluster: @cluster"]]},"id":"43f2fd74-135b-4d79-b320-90f4485b768e","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["cluster","tweet","y","x","line_color","fill_color"],"data":{"cluster":{"__ndarray__":"...","dtype":"int32","shape":[10000]},"fill_color":["#17becf","#1f77b4","#2ca02c","#e377c2","#1f77b4","#c49c94","#17becf","#9467bd","#9467bd","#2ca02c","#2ca02c","#9467bd","#2ca02c","#aec7e8","#aec7e8","#ffbb78","#c7c7c7","#9467bd","#aec7e8","#1f77b4","#9edae5","#ffbb78","#ffbb78","#c49c94","#e377c2","#aec7e8","#1f77b4","#8c564b","#17becf","#9467bd","#ffbb78","#e377c2","#c7c7c7","#17becf","#2ca02c","#bcbd22","#aec7e8","#f7b6d2","#17becf","#ffbb78","#f7b6d2","#aec7e8","#e377c2","#2ca02c","#e377c2","#c7c7c7","#aec7e8","#17becf","#9edae5","#17becf","#1f77b4","#9467bd","#ffbb78","#9467bd","#ffbb78","#ffbb78","#ffbb78","#aec7e8","#9467bd","#dbdb8d","#98df8a","#dbdb8d","#c7c7c7","#17becf","#2ca02c","#dbdb8d","#e377c2","#e377c2","#9467bd","#dbdb8d","#1f77b4","#17becf","#aec7e8","#dbdb8d","#17becf","#bcbd22","#98df8a","#dbdb8d","#dbdb8d","#e377c2","#c7c7c7","#2ca02c","#aec7e8","#c7c7c7","#aec7e8","#9467bd","#c7c7c7","#2ca02c","#2ca02c","#c7c7c7","#9467bd","#c7c7c7","#9467bd","#9467bd","#9467bd","#9467bd","#c7c7c7","#2ca02c","#2ca02c","#c7c7c7","#2ca02c","#ffbb78","#17becf","#ffbb78","#2ca02c","#9467bd","#7f7f7f","#9467bd","#1f77b4","#9edae5","#9467bd","#c7c7c7","#2ca02c","#c7c7c7","#c7c7c7","#c7c7c7","#aec7e8","#aec7e8","#c49c94","#aec7e8","#9467bd","#17becf","#17becf","#2ca02c","#2ca02c","#2ca02c","#c5b0d5","#17becf","#9467bd","#9467bd","#9467bd","#9467bd","#2ca02c","#2ca02c","#9467bd","#c7c7c7","#9467bd","#2ca02c","#2ca02c","#aec7e8","#c7c7c7","#ffbb78","#aec7e8","#9467bd","#2ca02c","#2ca02c","#c5b0d5","#1f77b4","#8c564b","#17becf","#1f77b4","#17becf","#98df8a","#1f77b4","#17becf","#d62728","#aec7e8","#f7b6d2","#9467bd","#1f77b4","#aec7e8","#bcbd22","#bcbd22","#c7c7c7","#98df8a","#ffbb78","#2ca02c","#98df8a","#e377c2","#1f77b4","#c7c7c7","#2ca02c","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#2ca02c","#c7c7c7","#c7c7c7","#2ca02c","#dbdb8d","#c7c7c7","#2ca02c","#c7c7c7","#2ca02c","#c7c7c7","#c7c7c7","#98df8a","#1f77b4","#ffbb78","#c49c94","#17becf","#1f77b4","#1f77b4","#bcbd22","#bcbd22","#17becf","#98df8a","#2ca02c","#9467bd","#c7c7c7","#9467bd","#2ca02c","#dbdb8d","#17becf","#1f77b4","#ff9896","#9467bd","#2ca02c","#c7c7c7","#17becf","#9467bd","#17becf","#9467bd","#c7c7c7","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#aec7e8","#c7c7c7","#aec7e8","#c7c7c7","#c7c7c7","#2ca02c","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#98df8a","#aec7e8","#c7c7c7","#98df8a","#c5b0d5","#c5b0d5","#d62728","#1f77b4","#c7c7c7","#8c564b","#8c564b","#aec7e8","#1f77b4","#98df8a","#2ca02c","#ff7f0e","#1f77b4","#aec7e8", ...

# %% [markdown]
# ## Within author aggregation

# %%
with open('./models/doc2vec_grp_model.kmeans', 'rb') as pickle_file:
    doc2vec_grp_kmeans = pickle.load(pickle_file)

doc2vec_grp_model = models.Doc2Vec.load('./models/doc2vec_grp_model.model')

tsne_kmeans_grp = tsne_model.fit_transform(doc2vec_grp_kmeans.transform(doc2vec_grp_model.docvecs))

# %% [markdown]
# ### Topic word list

# %%
grp_tweets = tweets.groupby('user').agg({'text': 'sum'})
grp_vectorizer = TfidfVectorizer(min_df=3, lowercase=True, stop_words=MY_ENGLISH_STOP_WORDS)
grp_tfidf = grp_vectorizer.fit_transform(grp_tweets.apply(lambda row: ' '.join(row.text), axis=1))

grp_feature_array = np.array(grp_vectorizer.get_feature_names())
for topic in range(0,20):
    tf_row = sum(grp_tfidf[[idx for idx, tp in enumerate(doc2vec_grp_kmeans.labels_) if tp == topic]])
    tfidf_sorting = np.argsort(tf_row.toarray()).flatten()[::-1]
    print('Topic %d: %s' % (topic, ' '.join(grp_feature_array[tfidf_sorting][:20])))
# Out:
# Topic 0: radiohead prince app unabridged hamilton iphone whatsapp ipad mac tvseries paulmccartney utilities rend games metgala drama 2016 nonfiction new comedy
# Topic 1: trump new police clinton says news brexit attack hillary convention 2016 man china donald 39 dallas watch france shooting killed
# Topic 2: july えどがわイケメン 2016 tos pm null pushawardslizquens mdbjss mtvhottest afe health gaga just love s0t people xxx like deals new
# Topic 3: twain shakespeare law mark william man like people good mencken time einstein does things life just albert know think make
# Topic 4: code use like shop available lit wear urbanattires 15 https 10 order shipping sale discount caps dope free promo checkout
# Topic 5: like love just want people need life ur know girl shit time isolated got wanna vocals beautiful make drake person
# Topic 6: nfl size deals shoes nba ebay new football dvd buzz sale tickets cd black weight basketball fashion 8x10 nike ncaa
# Topic 7: photos apply alert job sex nigeria nigerian buhari position video lagos photo pics limited manager penis things officer ways porn
# Topic 8: trump hillary clinton bernie https dnc neverhillary vote sanders demsinphilly people obama just demexit berniesanders rncincle donald police bernieorbust america
# Topic 9: sorry hi dm cr delta thanks cont hear help 93 apologies hey staples inconvenience team jh check assist flight know
# Topic 10: win gamedev follow https giveaway overwatch indiedev xb1 new like july enter competition just cricket dm 2016 video ps4 live
# Topic 11: july 2016 pm gbp ipl corp rating nowplaying zacks null ovs tos ascendant join free mediumcoeli plc ut classroom updates
# Topic 12: 2016 july mind sleeve following pm tweet love follow hi beautiful handbag thank betsey liked heart tunic deserve sleeveless dear
# Topic 13: sex later woman girl mom people shocking photos like girls just years things know wife happens dad daughter looks guy
# Topic 14: bid size black shoes nike apple new mens 16gb leather silver sz vintage air white iphone jordan retro unlocked ebay
# Topic 15: news tech business police new sports trump usa jobs itunes jobsearch reuters ndtv apple russia says clinton forbes topnews world
# Topic 16: marketing https asmsg business book quote seo iartg socialmedia free tech content bitcoin contentmarketing growthhacking books etsy startups startup bigdata
# Topic 17: aldubiyamin8days aldubfindinglola aldubpoweroftwo happy aldubiyamin5days aldubmainecelebration aldub51stweeksary love aldub1stanniversary aldubsafezone happy1stmaineniversary thank dear aldubimagineyouandme aldubiyamin7days aldub54thweeksary aldubsaklola aldubangpagdukot aldub52ndweeksary aldubiyambukasna
# Topic 18: villa manga luxury peacenotwar lovenothate spain tentsile nwo rebellion tents youaretheart reserve club kayak new notofascism notoracism freehugs grid settled
# Topic 19: jobs assistant hiring manager engineer job apply sales description tx 3bd jobsearch specialist opportunity location customer 2bd associate communityscene reps

# %% [markdown]
# ### Viz

# %%
plot_kmeans_grp = bp.figure(plot_width=900, plot_height=700,
                            x_axis_type=None, y_axis_type=None, min_border=1,
                            tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave")

plot_kmeans_grp.scatter(x=tsne_kmeans_grp[:,0], y=tsne_kmeans_grp[:,1], 
                        color=colormap[doc2vec_grp_kmeans.labels_],
                        source=bp.ColumnDataSource({
                            "cluster": doc2vec_grp_kmeans.labels_
                        }))

grp_hover = plot_kmeans_grp.select(dict(type=HoverTool))
grp_hover.tooltips={"cluster": "@cluster"}
show(plot_kmeans_grp)
